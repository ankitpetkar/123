# %%
import os, sys, time, random
import numpy as np
import keras.backend as K
from collections import defaultdict
from keras.datasets import mnist
from keras.utils.generic_utils import Progbar
from keras.optimizers import Adam
from keras.models import *
from keras.layers import *
from keras.preprocessing import image
from PIL import Image
time.clock()

np.random.seed(1333)
K.set_image_dim_ordering('tf')

from model import BuildGenerator, BuildDiscriminator

# params
nb_epochs = 500
batch_size = 1
p_lambda = 10

imgsize = 256

adam_lr = 0.000005
adam_beta_1 = 0.5

imgdirA = 'apple2orange/trainA'
imgdirB = 'apple2orange/trainB'
testimgdirA = 'apple2orange/testA'
testimgdirB = 'apple2orange/testB'

modeldir = 'data/'
testimgdir = 'images/'


modelG = BuildGenerator(Input(shape=(imgsize,imgsize,3)))
modelF = BuildGenerator(Input(shape=(imgsize,imgsize,3)))
modelDG = BuildDiscriminator(Input(shape=(imgsize,imgsize,3)))
modelDF = BuildDiscriminator(Input(shape=(imgsize,imgsize,3)))

modelG.summary()
modelDG.summary()

try:
	modelG.load_weights( os.path.join(modeldir, 'modelG.h5' ))
	modelF.load_weights( os.path.join(modeldir, 'modelF.h5' ))
	modelDG.load_weights(os.path.join(modeldir, 'modelDG.h5'))
	modelDF.load_weights(os.path.join(modeldir, 'modelDF.h5'))	
except Exception as e: 
	print(e)

modelDG.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')
modelDF.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')
modelG.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')
modelF.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')

imageReal = Input(shape=(imgsize,imgsize,3))
imageFake = Input(shape=(imgsize,imgsize,3))
DGReal, DGFake = modelDG(imageReal), modelDG(imageFake)
combDG = Model(inputs=[imageReal, imageFake], outputs=[DGReal, DGFake])
combDG.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')

imageReal = Input(shape=(imgsize,imgsize,3))
imageFake = Input(shape=(imgsize,imgsize,3))
DFReal, DFFake = modelDF(imageReal), modelDF(imageFake)
combDF = Model(inputs=[imageReal, imageFake], outputs=[DFReal, DFFake])
combDF.compile(optimizer=Adam(adam_lr, adam_beta_1), loss='mse')

imageA = Input(shape=(imgsize,imgsize,3))
imageB = Input(shape=(imgsize,imgsize,3))
modelDG.trainable = False
modelDF.trainable = False
fakeB, fakeA = modelG(imageA), modelF(imageB)
disG, disF = modelDG(fakeB), modelDF(fakeA)
cycGF, cycFG = modelF(fakeB), modelG(fakeA)
combM = Model(inputs=[imageA, imageB], outputs=[disG, disF, cycGF, cycFG])
combM.compile(optimizer=Adam(adam_lr, adam_beta_1), loss=['mse','mse','mae','mae'], loss_weights=[1, 1, p_lambda, p_lambda])

def ImgGenerator(imgdir):
	imglst = [os.path.join(imgdir, x) for x in os.listdir(imgdir)]
	while True:
		random.shuffle(imglst)
		for fn in imglst:
			img = image.load_img(fn, target_size=(imgsize, imgsize))
			img = (image.img_to_array(img) - 127.5) / 127.5
			yield np.expand_dims(img, axis=0)

# if the memory is enough for all imgs ...
def ImgGeneratorS(imgdir):
	imglst = [os.path.join(imgdir, x) for x in os.listdir(imgdir)]
	X = np.zeros((len(imglst), imgsize, imgsize, 3))
	for i, fn in enumerate(imglst):
		if i % 20 == 0: print('%d/%d' % (i, len(imglst)))
		img = image.load_img(fn, target_size=(imgsize, imgsize))
		X[i] = image.img_to_array(img)
	X = (X - 127.5) / 127.5
	ids = list(range(len(imglst)))
	while True:
		random.shuffle(ids)
		for ii in ids: yield X[ii:ii+1]

genA = ImgGeneratorS(imgdirA)
genB = ImgGeneratorS(imgdirB)
testA = ImgGenerator(testimgdirA)
testB = ImgGenerator(testimgdirB)

nb_batches = len(os.listdir(imgdirA)) // batch_size
ones = np.ones(   (batch_size, imgsize//16, imgsize//16, 1) )
zeros = np.zeros( (batch_size, imgsize//16, imgsize//16, 1) )


recordG, recordF = [], []
for epoch in range(nb_epochs):
	print('Epoch %d of %d' % (epoch+1, nb_epochs))
	progress_bar = Progbar(target=nb_batches)
	
	lossDG, lossDF = 0.5, 0.5
	for index in range(nb_batches):
		A_image_batch, B_image_batch = next(genA), next(genB)

		generateG = modelG.predict_on_batch(A_image_batch)
		recordG.append(generateG)
		if len(recordG) > 100: recordG = recordG[-50:]
		lossDG = combDG.train_on_batch([B_image_batch, random.choice(recordG)], [ones, zeros])[0]

		generateF = modelF.predict_on_batch(B_image_batch)
		recordF.append(generateF)
		if len(recordF) > 100: recordF = recordF[-50:]
		lossDF = combDF.train_on_batch([A_image_batch, random.choice(recordF)], [ones, zeros])[0]

		for _ in range(1):
			A_image_batch, B_image_batch = next(genA), next(genB)
			_, lossG, lossF, losscycGF, losscycFG = combM.train_on_batch([A_image_batch, B_image_batch], [ones, ones, A_image_batch, B_image_batch])

		progress_bar.update(index+1, values=[('DG',lossDG),('G',lossG),('DF',lossDF),('F',lossF),('cycGF',losscycGF),('cycFG',losscycFG)])

	print('Testing for epoch {}:'.format(epoch + 1))

	modelG.save_weights( os.path.join(modeldir, 'modelG.h5' ), True)
	modelF.save_weights( os.path.join(modeldir, 'modelF.h5' ), True)
	modelDG.save_weights(os.path.join(modeldir, 'modelDG.h5'), True)
	modelDF.save_weights(os.path.join(modeldir, 'modelDF.h5'), True)
	
	tA = np.concatenate( [next(testA) for x in range(4)], axis=0 ) 
	tB = np.concatenate( [next(testB) for x in range(4)], axis=0 ) 
	gG = modelG.predict(tA, batch_size=1)
	gF = modelF.predict(tB, batch_size=1)
	tA = tA.reshape(-1,imgsize,3)
	tB = tB.reshape(-1,imgsize,3)
	gG = gG.reshape(-1,imgsize,3)
	gF = gF.reshape(-1,imgsize,3)
	img = np.concatenate([tA, gG, tB, gF], axis=1)
	img = (img * 127.5 + 127.5).astype(np.uint8)  
	Image.fromarray(img).save(os.path.join(testimgdir, 'plot_epoch_{0:03d}_generated.png'.format(epoch)))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_21 (InputLayer)            (None, 256, 256, 3)   0
# ____________________________________________________________________________________________________
# lambda_105 (Lambda)              (None, 262, 262, 3)   0           input_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_117 (Conv2D)              (None, 256, 256, 32)  4736        lambda_105[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_109 (LeakyReLU)      (None, 256, 256, 32)  0           conv2d_117[0][0]
# ____________________________________________________________________________________________________
# lambda_106 (Lambda)              (None, 258, 258, 32)  0           leaky_re_lu_109[0][0]
# ____________________________________________________________________________________________________
# conv2d_118 (Conv2D)              (None, 128, 128, 64)  18496       lambda_106[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)      (None, 128, 128, 64)  0           conv2d_118[0][0]
# ____________________________________________________________________________________________________
# lambda_107 (Lambda)              (None, 130, 130, 64)  0           leaky_re_lu_110[0][0]
# ____________________________________________________________________________________________________
# conv2d_119 (Conv2D)              (None, 64, 64, 128)   73856       lambda_107[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_119[0][0]
# ____________________________________________________________________________________________________
# lambda_108 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_111[0][0]
# ____________________________________________________________________________________________________
# conv2d_120 (Conv2D)              (None, 64, 64, 128)   147584      lambda_108[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_120[0][0]
# ____________________________________________________________________________________________________
# lambda_109 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_112[0][0]
# ____________________________________________________________________________________________________
# conv2d_121 (Conv2D)              (None, 64, 64, 128)   147584      lambda_109[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_121[0][0]
# ____________________________________________________________________________________________________
# add_37 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_113[0][0]
#                                                                    leaky_re_lu_111[0][0]
# ____________________________________________________________________________________________________
# lambda_110 (Lambda)              (None, 66, 66, 128)   0           add_37[0][0]
# ____________________________________________________________________________________________________
# conv2d_122 (Conv2D)              (None, 64, 64, 128)   147584      lambda_110[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_122[0][0]
# ____________________________________________________________________________________________________
# lambda_111 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_114[0][0]
# ____________________________________________________________________________________________________
# conv2d_123 (Conv2D)              (None, 64, 64, 128)   147584      lambda_111[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_123[0][0]
# ____________________________________________________________________________________________________
# add_38 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_115[0][0]
#                                                                    add_37[0][0]
# ____________________________________________________________________________________________________
# lambda_112 (Lambda)              (None, 66, 66, 128)   0           add_38[0][0]
# ____________________________________________________________________________________________________
# conv2d_124 (Conv2D)              (None, 64, 64, 128)   147584      lambda_112[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_116 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_124[0][0]
# ____________________________________________________________________________________________________
# lambda_113 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_116[0][0]
# ____________________________________________________________________________________________________
# conv2d_125 (Conv2D)              (None, 64, 64, 128)   147584      lambda_113[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_117 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_125[0][0]
# ____________________________________________________________________________________________________
# add_39 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_117[0][0]
#                                                                    add_38[0][0]
# ____________________________________________________________________________________________________
# lambda_114 (Lambda)              (None, 66, 66, 128)   0           add_39[0][0]
# ____________________________________________________________________________________________________
# conv2d_126 (Conv2D)              (None, 64, 64, 128)   147584      lambda_114[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_118 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_126[0][0]
# ____________________________________________________________________________________________________
# lambda_115 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_118[0][0]
# ____________________________________________________________________________________________________
# conv2d_127 (Conv2D)              (None, 64, 64, 128)   147584      lambda_115[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_119 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_127[0][0]
# ____________________________________________________________________________________________________
# add_40 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_119[0][0]
#                                                                    add_39[0][0]
# ____________________________________________________________________________________________________
# lambda_116 (Lambda)              (None, 66, 66, 128)   0           add_40[0][0]
# ____________________________________________________________________________________________________
# conv2d_128 (Conv2D)              (None, 64, 64, 128)   147584      lambda_116[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_120 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_128[0][0]
# ____________________________________________________________________________________________________
# lambda_117 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_120[0][0]
# ____________________________________________________________________________________________________
# conv2d_129 (Conv2D)              (None, 64, 64, 128)   147584      lambda_117[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_121 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_129[0][0]
# ____________________________________________________________________________________________________
# add_41 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_121[0][0]
#                                                                    add_40[0][0]
# ____________________________________________________________________________________________________
# lambda_118 (Lambda)              (None, 66, 66, 128)   0           add_41[0][0]
# ____________________________________________________________________________________________________
# conv2d_130 (Conv2D)              (None, 64, 64, 128)   147584      lambda_118[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_122 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_130[0][0]
# ____________________________________________________________________________________________________
# lambda_119 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_122[0][0]
# ____________________________________________________________________________________________________
# conv2d_131 (Conv2D)              (None, 64, 64, 128)   147584      lambda_119[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_123 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_131[0][0]
# ____________________________________________________________________________________________________
# add_42 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_123[0][0]
#                                                                    add_41[0][0]
# ____________________________________________________________________________________________________
# lambda_120 (Lambda)              (None, 66, 66, 128)   0           add_42[0][0]
# ____________________________________________________________________________________________________
# conv2d_132 (Conv2D)              (None, 64, 64, 128)   147584      lambda_120[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_124 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_132[0][0]
# ____________________________________________________________________________________________________
# lambda_121 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_124[0][0]
# ____________________________________________________________________________________________________
# conv2d_133 (Conv2D)              (None, 64, 64, 128)   147584      lambda_121[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_125 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_133[0][0]
# ____________________________________________________________________________________________________
# add_43 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_125[0][0]
#                                                                    add_42[0][0]
# ____________________________________________________________________________________________________
# lambda_122 (Lambda)              (None, 66, 66, 128)   0           add_43[0][0]
# ____________________________________________________________________________________________________
# conv2d_134 (Conv2D)              (None, 64, 64, 128)   147584      lambda_122[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_126 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_134[0][0]
# ____________________________________________________________________________________________________
# lambda_123 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_126[0][0]
# ____________________________________________________________________________________________________
# conv2d_135 (Conv2D)              (None, 64, 64, 128)   147584      lambda_123[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_127 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_135[0][0]
# ____________________________________________________________________________________________________
# add_44 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_127[0][0]
#                                                                    add_43[0][0]
# ____________________________________________________________________________________________________
# lambda_124 (Lambda)              (None, 66, 66, 128)   0           add_44[0][0]
# ____________________________________________________________________________________________________
# conv2d_136 (Conv2D)              (None, 64, 64, 128)   147584      lambda_124[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_128 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_136[0][0]
# ____________________________________________________________________________________________________
# lambda_125 (Lambda)              (None, 66, 66, 128)   0           leaky_re_lu_128[0][0]
# ____________________________________________________________________________________________________
# conv2d_137 (Conv2D)              (None, 64, 64, 128)   147584      lambda_125[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_129 (LeakyReLU)      (None, 64, 64, 128)   0           conv2d_137[0][0]
# ____________________________________________________________________________________________________
# add_45 (Add)                     (None, 64, 64, 128)   0           leaky_re_lu_129[0][0]
#                                                                    add_44[0][0]
# ____________________________________________________________________________________________________
# lambda_126 (Lambda)              (None, 128, 128, 128) 0           add_45[0][0]
# ____________________________________________________________________________________________________
# lambda_127 (Lambda)              (None, 130, 130, 128) 0           lambda_126[0][0]
# ____________________________________________________________________________________________________
# conv2d_138 (Conv2D)              (None, 128, 128, 64)  73792       lambda_127[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_130 (LeakyReLU)      (None, 128, 128, 64)  0           conv2d_138[0][0]
# ____________________________________________________________________________________________________
# lambda_128 (Lambda)              (None, 256, 256, 64)  0           leaky_re_lu_130[0][0]
# ____________________________________________________________________________________________________
# lambda_129 (Lambda)              (None, 258, 258, 64)  0           lambda_128[0][0]
# ____________________________________________________________________________________________________
# conv2d_139 (Conv2D)              (None, 256, 256, 32)  18464       lambda_129[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_131 (LeakyReLU)      (None, 256, 256, 32)  0           conv2d_139[0][0]
# ____________________________________________________________________________________________________
# lambda_130 (Lambda)              (None, 258, 258, 32)  0           leaky_re_lu_131[0][0]
# ____________________________________________________________________________________________________
# conv2d_140 (Conv2D)              (None, 256, 256, 3)   867         lambda_130[0][0]
# ====================================================================================================
# Total params: 2,846,723
# Trainable params: 2,846,723
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 128, 128, 64)      9472
# _________________________________________________________________
# instance_normalization_17 (I (None, 128, 128, 64)      128
# _________________________________________________________________
# leaky_re_lu_155 (LeakyReLU)  (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_166 (Conv2D)          (None, 64, 64, 128)       73856
# _________________________________________________________________
# instance_normalization_18 (I (None, 64, 64, 128)       256
# _________________________________________________________________
# leaky_re_lu_156 (LeakyReLU)  (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_167 (Conv2D)          (None, 32, 32, 256)       295168
# _________________________________________________________________
# instance_normalization_19 (I (None, 32, 32, 256)       512
# _________________________________________________________________
# leaky_re_lu_157 (LeakyReLU)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_168 (Conv2D)          (None, 16, 16, 512)       1180160
# _________________________________________________________________
# instance_normalization_20 (I (None, 16, 16, 512)       1024
# _________________________________________________________________
# leaky_re_lu_158 (LeakyReLU)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_169 (Conv2D)          (None, 16, 16, 1)         4609
# =================================================================
# Total params: 1,565,185
# Trainable params: 1,565,185
# Non-trainable params: 0
# _________________________________________________________________
# Unable to open file (File signature not found)
# Epoch 1 of 500
# 0/67
# 20/67
# 40/67
# 60/67
# 0/55
# 20/55
# 40/55
# 67/67 [==============================] - 53s - DG: 1.4286 - G: 0.6602 - DF: 2.5876 - F: 1.7745 - cycGF: 0.5163 - cycFG: 0.3834
